# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
df = pd.read_csv(Path(r'../data/01_raw/raw_links.csv'))

# %%
df.duplicated().value_counts()
# Out:
# True     12076
# False     8717
# dtype: int64

# %%
df
# Out:
#                                             account_link       search_keywords
# 0              https://www.linkedin.com/in/vadim-sadykov              frontend
# 1              https://www.linkedin.com/in/vadim-sadykov              frontend
# 2      https://www.linkedin.com/in/ACoAADta9FgB_futxt...              frontend
# 3      https://www.linkedin.com/in/artem-volkov-06096...              frontend
# 4      https://www.linkedin.com/in/artem-volkov-06096...              frontend
# ...                                                  ...                   ...
# 20788  https://www.linkedin.com/in/yuliya-lukonina-qa...  middle test engineer
# 20789             https://www.linkedin.com/in/sobolishqo         middle devops
# 20790             https://www.linkedin.com/in/sobolishqo         middle devops
# 20791  https://www.linkedin.com/in/%D0%B5%D1%80%D1%88...         middle devops
# 20792  https://www.linkedin.com/in/%D0%B5%D1%80%D1%88...         middle devops
#
# [20793 rows x 2 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                             account_link       search_keywords
# 0              https://www.linkedin.com/in/vadim-sadykov              frontend
# 2      https://www.linkedin.com/in/ACoAADta9FgB_futxt...              frontend
# 3      https://www.linkedin.com/in/artem-volkov-06096...              frontend
# 5      https://www.linkedin.com/in/ACoAAAwULysB9ESOWu...              frontend
# 6                https://www.linkedin.com/in/alfrolov016              frontend
# ...                                                  ...                   ...
# 20783  https://www.linkedin.com/in/%D0%B2%D0%BB%D0%B0...  middle test engineer
# 20785  https://www.linkedin.com/in/dmitry-yakovlev-51...  middle test engineer
# 20787  https://www.linkedin.com/in/yuliya-lukonina-qa...  middle test engineer
# 20789             https://www.linkedin.com/in/sobolishqo         middle devops
# 20791  https://www.linkedin.com/in/%D0%B5%D1%80%D1%88...         middle devops
#
# [8717 rows x 2 columns]

# %%
fig, ax = plt.subplots()
ax.hist(x=df['search_keywords'], bins=np.arange(-0.5, 36), rwidth=0.7)
ax.set_xticks(ticks=np.arange(0, 36))
plt.xticks(rotation=90)
plt.show()

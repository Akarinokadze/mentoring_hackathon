# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
from os import listdir
from os.path import isfile, join

# %%
onlyfiles = [f for f in listdir(Path(r'../data/01_raw/')) if isfile(join(Path(r'../data/01_raw/'), f))]

# %%
onlyfiles.remove('.gitkeep')
onlyfiles.remove('raw_links.csv')
onlyfiles
# Out:
# ['0-50.csv',
#  '100-150.csv',
#  '1150-1200.csv',
#  '150-200.csv',
#  '1500-1560.csv',
#  '1700-1728.csv',
#  '1900-1950.csv',
#  '200-250.csv',
#  '2900-3000.csv',
#  '3150-3250.csv',
#  '3300-3350.csv',
#  '350-400.csv',
#  '3700-3750.csv',
#  '3750-3800.csv',
#  '4000-4050.csv',
#  '4000-4150.csv',
#  '4500-4528.csv',
#  '50-100.csv',
#  '500-550.csv',
#  '5000-5150.csv']

# %%
for i in range(len(onlyfiles)):
    onlyfiles[i] = r'../data/01_raw/' + onlyfiles[i]

# %%
onlyfiles
# Out:
# ['../data/01_raw/0-50.csv',
#  '../data/01_raw/100-150.csv',
#  '../data/01_raw/1150-1200.csv',
#  '../data/01_raw/150-200.csv',
#  '../data/01_raw/1500-1560.csv',
#  '../data/01_raw/1700-1728.csv',
#  '../data/01_raw/1900-1950.csv',
#  '../data/01_raw/200-250.csv',
#  '../data/01_raw/2900-3000.csv',
#  '../data/01_raw/3150-3250.csv',
#  '../data/01_raw/3300-3350.csv',
#  '../data/01_raw/350-400.csv',
#  '../data/01_raw/3700-3750.csv',
#  '../data/01_raw/3750-3800.csv',
#  '../data/01_raw/4000-4050.csv',
#  '../data/01_raw/4000-4150.csv',
#  '../data/01_raw/4500-4528.csv',
#  '../data/01_raw/50-100.csv',
#  '../data/01_raw/500-550.csv',
#  '../data/01_raw/5000-5150.csv']

# %%
df0 = pd.read_csv(Path(onlyfiles[0]))
df1 = pd.read_csv(Path(onlyfiles[1]))
df2 = pd.read_csv(Path(onlyfiles[2]))
df3 = pd.read_csv(Path(onlyfiles[3]))
df4 = pd.read_csv(Path(onlyfiles[4]))
df5 = pd.read_csv(Path(onlyfiles[5]))
df6 = pd.read_csv(Path(onlyfiles[6]))
df7 = pd.read_csv(Path(onlyfiles[7]))
df8 = pd.read_csv(Path(onlyfiles[8]))
df9 = pd.read_csv(Path(onlyfiles[9]))
df10 = pd.read_csv(Path(onlyfiles[10]))
df11 = pd.read_csv(Path(onlyfiles[11]))
df12 = pd.read_csv(Path(onlyfiles[12]))
df13 = pd.read_csv(Path(onlyfiles[13]))
df14 = pd.read_csv(Path(onlyfiles[14]))
df15 = pd.read_csv(Path(onlyfiles[15]))
df16 = pd.read_csv(Path(onlyfiles[16]))
df17 = pd.read_csv(Path(onlyfiles[18]))
df18 = pd.read_csv(Path(onlyfiles[19]))

# %%
df_list = []
for i in range(19):
    df_list.append('df'+str(i))

# %%
df_list
# Out:
# ['df0',
#  'df1',
#  'df2',
#  'df3',
#  'df4',
#  'df5',
#  'df6',
#  'df7',
#  'df8',
#  'df9',
#  'df10',
#  'df11',
#  'df12',
#  'df13',
#  'df14',
#  'df15',
#  'df16',
#  'df17',
#  'df18']

# %%
df.iloc[3]['account_link']
# Out:
# 'https://www.linkedin.com/in/yuri-arsentiev-a0a958b7'

# %%
df = pd.read_csv(Path(r'../data/01_raw/raw_links.csv'))

# %%
df2 = pd.read_csv(Path(r'../data/01_raw/raw_links alina.csv'))

# %%
df3 = pd.read_csv(Path(r'../data/01_raw/data_frame(Nel).csv'))

# %%
result = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9,
                    df10, df11, df12, df13, df14, df15, df16, df17, df18])

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4865 entries, 0 to 991
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   account_link     4865 non-null   object
#  1   search_keywords  4865 non-null   object
#  2   name             4865 non-null   object
#  3   title            4865 non-null   object
#  4   works_at         4180 non-null   object
#  5   intro            4864 non-null   object
#  6   experience       4859 non-null   float64
#  7   place            4864 non-null   object
#  8   posts_cnt        4865 non-null   int64
#  9   post_text        2374 non-null   object
#  10  reaction_cnt     2027 non-null   float64
#  11  comments_cnt     1050 non-null   float64
#  12  repost_cnt       1169 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 532.1+ KB

# %%
fig, ax = plt.subplots()
ax.hist(x=df['search_keywords'], bins=np.arange(-0.5, 36), rwidth=0.7)
ax.set_xticks(ticks=np.arange(0, 36))
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(x=df2['search_keywords'], bins=np.arange(-0.5, 36), rwidth=0.7)
ax.set_xticks(ticks=np.arange(0, 36))
ax.grid(axis='y')
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(x=df3['search_keywords'], bins=np.arange(-0.5, 36), rwidth=0.7)
ax.set_xticks(ticks=np.arange(0, 36))
ax.grid(axis='y')
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(x=result['search_keywords'], bins=np.arange(-0.5, 36), rwidth=0.7)
ax.set_xticks(ticks=np.arange(0, 36))
ax.grid(axis='y')
plt.xticks(rotation=90)
plt.show()

# %%
len(result['search_keywords'].unique())
# Out:
# 36

# %%
result.to_csv(Path(r'../data/01_raw/raw_posts.csv'), index=False)

# %%
dfc = pd.read_csv(Path(r'../data/02_intermediate/clean_links.csv'))

# %%
fig, ax = plt.subplots()
ax.hist(x=dfc['search_keywords'], bins=np.arange(-0.5, 36), rwidth=0.7)
ax.set_xticks(ticks=np.arange(0, 36))
ax.grid(axis='y')
plt.xticks(rotation=90)
plt.show()

# %%
df = pd.read_csv(Path(r'../data/02_intermediate/clean_links.csv'))

# %%
df
# Out:
#                                             account_link  search_keywords
# 0              https://www.linkedin.com/in/vadim-sadykov         frontend
# 1      https://www.linkedin.com/in/ACoAADta9FgB_futxt...         frontend
# 2      https://www.linkedin.com/in/artem-volkov-06096...         frontend
# 3      https://www.linkedin.com/in/ACoAAAwULysB9ESOWu...         frontend
# 4                https://www.linkedin.com/in/alfrolov016         frontend
# ...                                                  ...              ...
# 11333  https://www.linkedin.com/in/ACoAAA9GfksBhqxIsj...  senior frontend
# 11334               https://www.linkedin.com/in/de-arnst  senior frontend
# 11335  https://www.linkedin.com/in/%D0%B2%D1%8F%D1%87...  senior frontend
# 11336  https://www.linkedin.com/in/ACoAAAK4fMsBJFW0NA...  senior frontend
# 11337  https://www.linkedin.com/in/anastasiya-telnova...  senior frontend
#
# [11338 rows x 2 columns]

# %%
for row in df[:5].iterrows():
    print(row[1]['account_link'])
# Out:
# https://www.linkedin.com/in/vadim-sadykov
# https://www.linkedin.com/in/ACoAADta9FgB_futxtmjKMyAPcONL3j87rikBVE
# https://www.linkedin.com/in/artem-volkov-060965185
# https://www.linkedin.com/in/ACoAAAwULysB9ESOWuq9KUe2R3NJcB3hy6RkKKM
# https://www.linkedin.com/in/alfrolov016

# %%
next(df.iterrows())
# Out:
# (0,
#  account_link       https://www.linkedin.com/in/vadim-sadykov
#  search_keywords                                     frontend
#  Name: 0, dtype: object)

# %%
df = pd.read_csv(Path(r'../data/02_intermediate/clean_posts.csv'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2081 entries, 0 to 2080
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   account_link     2081 non-null   object
#  1   search_keywords  2081 non-null   object
#  2   name             2081 non-null   object
#  3   title            2081 non-null   object
#  4   works_at         1895 non-null   object
#  5   intro            2080 non-null   object
#  6   experience       2075 non-null   float64
#  7   place            2080 non-null   object
#  8   posts_cnt        2081 non-null   int64
#  9   post_text        1225 non-null   object
#  10  reaction_cnt     1005 non-null   float64
#  11  comments_cnt     453 non-null    float64
#  12  repost_cnt       453 non-null    float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 211.5+ KB
